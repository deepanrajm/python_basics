# %% [markdown]
# # **String**

# %%
a = "Python"
b = " is python awesome!"

print(len(a))                        
print(len(b))

# %%
print(a + b)                         
print(a, b)

# %%
print(a.upper())                    
print(a.lower())

# %%
print(b.strip())                     
print(b.replace("awesome", "great"))

# %%
print(' '.join(a))
print('-'.join(a))

# %%
a='Mathematics'

# %%
a[5]

# %%
a[0]

# %%
a[-1]

# %%
a[-3]

# %%
a[0:2]

# %%
a[1:5]

# %%
a[0:]

# %%
a[:11]

# %%
a[1:6:2]

# %%
a[::-1]

# %%
a[-1:-4]

# %%
a[-1:3]

# %%
a[3:-3]

# %%
a[-3:-2]

# %%
a[:-4]

# %%
a[-1:]

# %%
a[:]

# %%
a[::]

# %%
a[:len(a)]

# %%
if a in b:
	print ("True")
else:
	print ("false")
